# %%
import numpy as np
a = 1

# %%
a
# Out:
# 1

# %%
1 + 5
# Out:
# 6

# %% [markdown]
# Bla bla bla pikny teksik

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %%html
#
# <h1> Pikny naglowek number one<h1>
# Out:
# <h1> Pikny naglowek number one<h1>

# %%
np.random.rand(5, 8)
# Out:
# array([[0.44674113, 0.82002915, 0.89404225, 0.22538454, 0.72796421,
#         0.62478147, 0.31166583, 0.42169271],
#        [0.6804318 , 0.77632324, 0.56556228, 0.97579319, 0.82215653,
#         0.38147118, 0.23456309, 0.69887441],
#        [0.08560577, 0.59039784, 0.053023  , 0.83184569, 0.41656158,
#         0.63205735, 0.87428039, 0.08838181],
#        [0.51222672, 0.76408786, 0.31763643, 0.32895605, 0.89746515,
#         0.19748502, 0.74004793, 0.75689651],
#        [0.92592965, 0.85974034, 0.70471297, 0.74934305, 0.8400763 ,
#         0.59423202, 0.72940385, 0.44876097]])

# %%
import matplotlib.pyplot as plt
x = np.linspace(1, 5, 100)
y = np.sin(x)
    
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
x = np.linspace(1, 30, 100)
y = np.sin(x)
    
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
x = np.linspace(5, 10, 50)
y = np.cos(y)
y2 = np.sin(y)

    
plt.plot(x, y)
plt.plot(x, y2)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace(1, 10, 100)
y = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y);
plt.plot(x, y2);
